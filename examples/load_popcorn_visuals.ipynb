# %% [markdown]
# <a href="https://colab.research.google.com/github/RecSys-lab/popcorn_dataset/blob/main/examples/load_popcorn_visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🍿 Popcorn Framework in Google Colab**
# ### **Load Popcorn Dataset - Frame/Shot Embedding Functions**
#
# 🤗 Dataset in HF: [link](https://huggingface.co/datasets/alitourani/Popcorn_Dataset)
#
# 🌐 Dataset Web-Page: [link](https://recsys-lab.github.io/popcorn_dataset/)
#
# 🎬 Popcorn Framework: [link](https://github.com/RecSys-lab/Popcorn)

# %% [markdown]
# ## **[Step 1] Clone Popcorn Movie Recommender Tool**
#
# Clone the framework into your `GDrive` and prepare it for experiments.
#
# ⚠️ You might see a *"Restart Session"* warning during the first run in Google Colab due to library version mismatches. This is expected! Accept the restart, re-run this cell, and continue!

# %%
# Clone the repo
# !git clone https://github.com/RecSys-lab/Popcorn.git

# Install the required library
# %cd Popcorn
# !pip install -e .

# Add the repository to the Python path
import sys
sys.path.append('/content/Popcorn')

# Go back to the root
# %cd ..
# Out:
# fatal: destination path 'Popcorn' already exists and is not an empty directory.
# /content/Popcorn
# Obtaining file:///content/Popcorn
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools==80.9.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (80.9.0)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (6.0.2)
# Requirement already satisfied: requests==2.32.5 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.32.5)
# Requirement already satisfied: pandas==2.3.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.3.0)
# Requirement already satisfied: numpy==2.3.2 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.3.2)
# Requirement already satisfied: scikit-learn==1.7.2 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (1.7.2)
# Requirement already satisfied: yt-dlp==2025.9.26 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2025.9.26)
# Requirement already satisfied: opencv-python==4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (4.11.0.86)
# Requirement already satisfied: keras==3.11.3 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (3.11.3)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.8.0+cu126)
# Requirement already satisfied: cornac==2.3.3 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.3.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cornac==2.3.3->Popcorn==1.6.0) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cornac==2.3.3->Popcorn==1.6.0) (4.67.1)
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.12/dist-packages (from cornac==2.3.3->Popcorn==1.6.0) (1.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.0->Popcorn==1.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.0->Popcorn==1.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.0->Popcorn==1.6.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.2->Popcorn==1.6.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.2->Popcorn==1.6.0) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.3.0->Popcorn==1.6.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->Popcorn==1.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->Popcorn==1.6.0) (3.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from powerlaw->cornac==2.3.3->Popcorn==1.6.0) (3.10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras==3.11.3->Popcorn==1.6.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras==3.11.3->Popcorn==1.6.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.11.3->Popcorn==1.6.0) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (3.2.5)
# Installing collected packages: Popcorn
#   Attempting uninstall: Popcorn
#     Found existing installation: Popcorn 1.6.0
#     Uninstalling Popcorn-1.6.0:
#       Successfully uninstalled Popcorn-1.6.0
#   Running setup.py develop for Popcorn
# Successfully installed Popcorn-1.6.0
# /content

# %% [markdown]
# ## 🚀 **[Step 2] Use the Framework**

# %% [markdown]
# ### *1. Load Configurations and Imports*

# %%
from popcorn.utils import readConfigs
from popcorn.datasets.popcorn.utils import RAW_DATA_URL
from popcorn.datasets.popcorn.helper_embedding import generatePacketUrl, fetchAllPackets

# Start the Framework
print("Welcome to 'Popcorn' 🍿! Starting the framework for your movie recommendation ...\n")

# Read the configuration file
configs = readConfigs("Popcorn/popcorn/config/config.yml")
# If properly read, print the configurations
if not configs:
    print("Error reading the configuration file!")
# Out:
# Welcome to 'Popcorn' 🍿! Starting the framework for your movie recommendation ...
#
# - Reading the framework's configuration file ...
# - Configuration file loaded successfully!

# %% [markdown]
# ### *2. Override the Configurations (Optional)*

# %%
# Which CNNs to use? ('incp3' | 'vgg19')
cnns = configs["datasets"]["multimodal"]["popcorn"]["cnns"]

# What is the Dataset name?
datasetName = configs["datasets"]["multimodal"]["popcorn"]["name"]

# Which Embedding Sources to Use? ('full_movies' | 'movie_shots' | 'movie_trailers')
embeddings = configs["datasets"]["multimodal"]["popcorn"]["embedding_sources"]

print(
    f"- Preparing to fetch the raw file of '{datasetName}' dataset from '{RAW_DATA_URL}' ..."
)
# Out:
# - Preparing to fetch the raw file of 'Popcorn-visual' dataset from 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/' ...

# %% [markdown]
# ### *3. Test Generating Sample Packet URLs*

# %%
print(f"\n[Func-1] Generating a sample packet URLs to embeddings ...")
givenMovieId, givenPacketId = 6, 1
givenCnn, givenEmbedding = cnns[0], embeddings[0]
packetUrl = generatePacketUrl(givenEmbedding, givenCnn, givenMovieId, givenPacketId)
print(
    f"- URL for packet '#{givenPacketId}' of movie '#{givenMovieId}' extracted by CNN '{givenCnn}' from source '{givenEmbedding}': {packetUrl}"
)

# Another sample
givenMovieId, givenPacketId = 150, 3
givenCnn, givenEmbedding = "vgg19", "movie_trailers"
packetUrl = generatePacketUrl(givenEmbedding, givenCnn, givenMovieId, givenPacketId)
print(
    f"- URL for packet '#{givenPacketId}' of movie '#{givenMovieId}' extracted by CNN '{givenCnn}' from source '{givenEmbedding}': {packetUrl}"
)
# Out:
# [Func-1] Generating a sample packet URLs to embeddings ...
# - URL for packet '#1' of movie '#6' extracted by CNN 'incp3' from source 'full_movies': https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/full_movies/incp3/0000000006/packet0001.json
# - URL for packet '#3' of movie '#150' extracted by CNN 'vgg19' from source 'movie_trailers': https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/vgg19/0000000150/packet0003.json

# %% [markdown]
# ### *4. Test Fetching All Packets of a Movie*

# %%
print(f"\n[Func-2] Fetching all packets of a movie ...")
givenMovieId = 6
givenCnn, givenEmbedding = "incp3", "movie_trailers"
fetchedEmbeddings = fetchAllPackets(givenEmbedding, givenCnn, givenMovieId)
print(
    f"- Number of embeddings from the fetched packets for movie '#{givenMovieId}': {len(fetchedEmbeddings)}"
)
# Out:
# [Func-2] Fetching all packets of a movie ...
# - Fetching all packets of the movie #6 (movie_trailers, incp3) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0001.json' ...
# - JSON data loaded successfully!
# - Fetched JSON data from the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0001.json'!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0002.json' ...
# - JSON data loaded successfully!
# - Fetched JSON data from the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0002.json'!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0003.json' ...
# - JSON data loaded successfully!
# - Fetched JSON data from the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0003.json'!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0004.json' ...
# - JSON data loaded successfully!
# - Fetched JSON data from the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0004.json'!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0005.json' ...
# - JSON data loaded successfully!
# - Fetched JSON data from the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0005.json'!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0006.json' ...
# - JSON data loaded successfully!
# - Fetched JSON data from the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0006.json'!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0007.json' ...
# - [Error] Error fetching data from https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0007.json: 404 Client Error: Not Found for url: https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0007.json
# - [Error] No JSON data found at the URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers/incp3/0000000006/packet0007.json'! Stopping ...
# - Number of embeddings from the fetched packets for movie '#6': 148
